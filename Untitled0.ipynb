# %%
######GET RID OF THIS FOR PY FILE!
# %matplotlib inline 
######

import graph
import numpy as np
import networkx as nx 
import matplotlib.pyplot as plt 


#Computes Z-score for each edge's congestion. If it's negative, make the factor 1. Else, take Z-score and add 1 and square
#root it for the multiply factor. Adjust weights and rerun shortest paths/congestion map. Do for n times.

#Note: if n=0, then it just runs shortest paths and draws the congestion map. The distances between stations are then not a
#function of congestion, but only the geographical distance.

def runCongestionAdjusted (g, n):
    
    numIterLeft = n
    g.calculateCongestion()
    
    while (numIterLeft > 0):

        congestions = g.congestion

        #Compute average and standard deviation of congestion numbers
        thesum = 0.0
        for i in congestions:
            thesum = thesum + congestions[i]
        average = thesum / g.num_stations

        sumsquares = 0.0
        for i in congestions:
            sumsquares = sumsquares + ((congestions[i] - average) * (congestions[i] - average))
        sdeviation = (1.0 / g.num_stations) * sumsquares

        #Update edge weights by multiplying by transformation of Z-score, if the Z-score is positive
        for aTuple in congestions:
            zscore = (congestions[aTuple] - average) / sdeviation
            
            if zscore > 0:
            
                index1 = aTuple[0]
                index2 = aTuple[1]

                oldweight = g.adj_matrix[index1][index2]
                
                #Multiply by sqrt(Z-score +1)
                g.adj_matrix[index1][index2] = oldweight * np.sqrt(zscore + 1.0)
                g.adj_matrix[index2][index1] = oldweight * np.sqrt(zscore + 1.0)
                g.adj_list[index1][index2] = oldweight * np.sqrt(zscore + 1.0)
                g.adj_list[index2][index1] = oldweight * np.sqrt(zscore + 1.0)
        
        #Update congestion edge weights using shortest path algorithms
        g.calculateCongestion()
          
        #Count how many iterations left to do
        numIterLeft = numIterLeft - 1
    
    #Draw the new graph congestion map
    g.draw(color)
    
'''   
#%% 
subway = graph.Graph(None,'BostonData.csv')               
 #%%               
def color(c): 
    return [ 1 - (1-c) ** 5, 0.8, 0]   

subway.draw(color)

#plt.savefig("path.png") # save as png
plt.title("Boston Subway System")
plt.show()

#%%

'''
# Out:
# '   \n#%% \nsubway = graph.Graph(None,\'BostonData.csv\')               \n #%%               \ndef color(c): \n    return [ 1 - (1-c) ** 5, 0.8, 0]   \n\nsubway.draw(color)\n\n#plt.savefig("path.png") # save as png\nplt.title("Boston Subway System")\nplt.show()\n\n#%%\n\n'

# %%
#%% 
subway = graph.Graph(None,'BostonData.csv')               
 #%%               
def color(c): 
    return [ 1 - (1-c) ** 5, 0.8, 0]   

runCongestionAdjusted(subway, 0)

#plt.savefig("path.png") # save as png
plt.title("Boston Subway System")
plt.show()

# %%
#%% 
subway = graph.Graph(None,'BostonData.csv')               
 #%%               
def color(c): 
    return [ 1 - (1-c) ** 5, 0.8, 0]   

runCongestionAdjusted(subway, 1)

#plt.savefig("path.png") # save as png
plt.title("Boston Subway System")
plt.show()

# %%
#%% 
subway = graph.Graph(None,'BostonData.csv')               
 #%%               
def color(c): 
    return [ 1 - (1-c) ** 5, 0.8, 0]   

runCongestionAdjusted(subway, 5)

#plt.savefig("path.png") # save as png
plt.title("Boston Subway System")
plt.show()

# %%
runCongestionAdjusted(subway, 5)

#plt.savefig("path.png") # save as png
plt.title("Boston Subway System")
plt.show()

# %%
######GET RID OF THIS FOR PY FILE!
# %matplotlib inline 
######

import graph
import numpy as np
import networkx as nx 
import matplotlib.pyplot as plt 


#Computes Z-score for each edge's congestion. If it's negative, make the factor 1. Else, take Z-score and add 1 and square
#root it for the multiply factor. Adjust weights and rerun shortest paths/congestion map. Do for n times.

#Note: if n=0, then it just runs shortest paths and draws the congestion map. The distances between stations are then not a
#function of congestion, but only the geographical distance.

def runCongestionAdjusted (g, n):
    
    numIterLeft = n
    g.calculateCongestion()
    
    while (numIterLeft > 0):

        congestions = g.congestion

        #Compute average and standard deviation of congestion numbers
        thesum = 0.0
        for i in congestions:
            thesum = thesum + congestions[i]
        average = thesum / g.num_stations

        sumsquares = 0.0
        for i in congestions:
            sumsquares = sumsquares + ((congestions[i] - average) * (congestions[i] - average))
        sdeviation = (1.0 / g.num_stations) * sumsquares

        #Update edge weights by multiplying by transformation of Z-score, if the Z-score is positive
        for aTuple in congestions:
            zscore = (congestions[aTuple] - average) / sdeviation
            
            if zscore > 0:
            
                index1 = aTuple[0]
                index2 = aTuple[1]

                oldweight = g.adj_matrix[index1][index2]
                
                #Multiply by sqrt(Z-score +1)
                g.adj_matrix[index1][index2] = oldweight * np.sqrt(zscore + 1.0)
                g.adj_matrix[index2][index1] = oldweight * np.sqrt(zscore + 1.0)
                g.adj_list[index1][index2] = oldweight * np.sqrt(zscore + 1.0)
                g.adj_list[index2][index1] = oldweight * np.sqrt(zscore + 1.0)
        
        #Update congestion edge weights using shortest path algorithms
        g.calculateCongestion()
          
        #Count how many iterations left to do
        numIterLeft = numIterLeft - 1
    
    #Draw the new graph congestion map
    g.draw(color)

# %%
# %matplotlib inline

# %%
# %run graph.py
# Out:
# Would you like Boston (B) or Paris (P)?
# B
# What would you like to do?
#
#         - See the Graph             (Type: 'G')
#         - Display a Congestion Map  (Type: 'D')
#         - Try Adding a New Edge     (Type: 'A')
#         - Run Simulation            (Type: 'S')
#         - Recommend a Route         (Type: 'R')
#         - Change the Algorithm      (Type: 'E')
#         - Exit                      (Type: 'Q')
# G
# Drawing Subway Map...
# Beginning to draw graph
# Calculating the congestion...
# Calculating Congestions
# This may take a while, especially on Paris
# What would you like to do?
#
#         - See the Graph             (Type: 'G')
#         - Display a Congestion Map  (Type: 'D')
#         - Try Adding a New Edge     (Type: 'A')
#         - Run Simulation            (Type: 'S')
#         - Recommend a Route         (Type: 'R')
#         - Change the Algorithm      (Type: 'E')
#         - Exit                      (Type: 'Q')
# S
# Simulating time...
# Calculating Congestions
# Beginning to draw graph
# What would you like to do?
#
#         - See the Graph             (Type: 'G')
#         - Display a Congestion Map  (Type: 'D')
#         - Try Adding a New Edge     (Type: 'A')
#         - Run Simulation            (Type: 'S')
#         - Recommend a Route         (Type: 'R')
#         - Change the Algorithm      (Type: 'E')
#         - Exit                      (Type: 'Q')
# R
# Calculating Congestions
# Type the name of the first station
# Harvard
# Type the name of the second station
# South Stations
# Sorry, that was not a valid station name
# South Station
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/robertchen/Documents/cs51final/graph.py in <module>()
#     572 #%%
#     573 if __name__ == "__main__":
# --> 574     s = main()
#     575
#
# /Users/robertchen/Documents/cs51final/graph.py in main()
#     521             subway.calculateCongestion()
#     522             station1, station2 = get_two_stations(subway)
# --> 523             path = subway.a_star(station1, station2, True)
#     524             result = ''
#     525             for p in path:
#
# /Users/robertchen/Documents/cs51final/graph.py in a_star(self, start_index, end_index, named_list, testing)
#     213
#     214     def a_star(self,start_index,end_index, named_list, testing = False):
# --> 215         return imported_a_star(self,start_index,end_index,named_list,testing)
#     216
#     217     def dijkstra(self, init, dest, data_structure, d = None,
#
# /Users/robertchen/Documents/cs51final/final_a_star.py in a_star(graph, start, goal, named_list, testing)
#      26                 return frontpath
#      27 #EXTEND THE FRONT PATH
# ---> 28         neighbors=graph.adj_list[frontpath[-1]].keys()
#      29         replacement=[]
#      30
#
# TypeError: list indices must be integers, not str

# %%
# %run graph.py
# Out:
# Would you like Boston (B) or Paris (P)?
# B
# What would you like to do?
#
#         - See the Graph             (Type: 'G')
#         - Display a Congestion Map  (Type: 'D')
#         - Try Adding a New Edge     (Type: 'A')
#         - Run Simulation            (Type: 'S')
#         - Recommend a Route         (Type: 'R')
#         - Change the Algorithm      (Type: 'E')
#         - Exit                      (Type: 'Q')
# D
# Drawing Congestion Map...
# Beginning to draw graph
# Calculating the congestion...
# Calculating Congestions
# This may take a while, especially on Paris
# What would you like to do?
#
#         - See the Graph             (Type: 'G')
#         - Display a Congestion Map  (Type: 'D')
#         - Try Adding a New Edge     (Type: 'A')
#         - Run Simulation            (Type: 'S')
#         - Recommend a Route         (Type: 'R')
#         - Change the Algorithm      (Type: 'E')
#         - Exit                      (Type: 'Q')
